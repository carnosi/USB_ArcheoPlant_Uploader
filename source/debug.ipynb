# %%
import dataprocess as dp
import uploader as up
from all_in_one import all_in_one as aio
path = r"C:\Users\anonn\Downloads\uploaded\2021-09-07"
test_path = r"C:\GitRepos\JCU_ArcheoPlant_Uploader\test"
json_path = r"C:\GitRepos\JCU_ArcheoPlant_Uploader\preload_data.json"

# %%
uper = up.Connector()

# %%
data = dp.preload_data(path, "zeiss", save=True)
# Out:
# Automatic image feature extraction failed! No data values are provided. Analyze the seed in path: C:\Users\anonn\Downloads\uploaded\2021-09-07\Alopecurus Pratensis\diaspore\alo pra_Hülle_1--01_c1.tif manually!
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# Automatic image feature extraction failed! No data values are provided. Analyze the seed in path: C:\Users\anonn\Downloads\uploaded\2021-09-07\Alopecurus Pratensis\diaspore\alo pra_Hülle_1--02_c1.tif manually!
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
uper.commit_all(json_path)
# Out:
# 1000000 bytes uploaded ...
# 2000000 bytes uploaded ...
# 3000000 bytes uploaded ...
# 4000000 bytes uploaded ...
# 5000000 bytes uploaded ...
# 6000000 bytes uploaded ...
# 7000000 bytes uploaded ...
# 8000000 bytes uploaded ...
# 9000000 bytes uploaded ...
# 10000000 bytes uploaded ...
# 11000000 bytes uploaded ...
# 12000000 bytes uploaded ...
# 13000000 bytes uploaded ...
# 14000000 bytes uploaded ...
# 15000000 bytes uploaded ...
# 15608238 bytes uploaded ...
# maximum upload specified(15608238 bytes) has been reached
# 1000000 bytes uploaded ...
# 2000000 bytes uploaded ...
# 3000000 bytes uploaded ...
# 4000000 bytes uploaded ...
# 5000000 bytes uploaded ...
# 6000000 bytes uploaded ...
# 7000000 bytes uploaded ...
# 8000000 bytes uploaded ...
# 9000000 bytes uploaded ...
# 10000000 bytes uploaded ...
# 11000000 bytes uploaded ...
# 12000000 bytes uploaded ...
# 13000000 bytes uploaded ...
# 14000000 bytes uploaded ...
# 15000000 bytes uploaded ...
# ...

# %%
pathik = r"C:\Users\anonn\Downloads\uploaded\2021-09-07\Hypericum Perforatum"
groups = dp.get_groups(pathik)

# %%
groups
# Out:
# [['C:/Users/anonn/Downloads/uploaded/2021-09-07/Hypericum Perforatum/Hypericum perforatum_1--01_c1.tif',
#   'C:/Users/anonn/Downloads/uploaded/2021-09-07/Hypericum Perforatum/Hypericum perforatum_1--02_c1.tif',
#   'C:/Users/anonn/Downloads/uploaded/2021-09-07/Hypericum Perforatum/Hypericum perforatum_1--03_c1.tif',
#   'C:/Users/anonn/Downloads/uploaded/2021-09-07/Hypericum Perforatum/Hypericum perforatum_1--04_c1.tif'],
#  ['C:/Users/anonn/Downloads/uploaded/2021-09-07/Hypericum Perforatum/Hypericum perforatum_10--01_c1.tif',
#   'C:/Users/anonn/Downloads/uploaded/2021-09-07/Hypericum Perforatum/Hypericum perforatum_10--02_c1.tif',
#   'C:/Users/anonn/Downloads/uploaded/2021-09-07/Hypericum Perforatum/Hypericum perforatum_10--03_c1.tif',
#   'C:/Users/anonn/Downloads/uploaded/2021-09-07/Hypericum Perforatum/Hypericum perforatum_10--04_c1.tif',
#   'C:/Users/anonn/Downloads/uploaded/2021-09-07/Hypericum Perforatum/Hypericum perforatum_10--05_c1.tif',
# ...

# %%
aio(test_path, "zeis")
# Out:
# 1000000 bytes uploaded ...
# 2000000 bytes uploaded ...
# 3000000 bytes uploaded ...
# 4000000 bytes uploaded ...
# 5000000 bytes uploaded ...
# 6000000 bytes uploaded ...
# 7000000 bytes uploaded ...
# 8000000 bytes uploaded ...
# 9000000 bytes uploaded ...
# 10000000 bytes uploaded ...
# 11000000 bytes uploaded ...
# 12000000 bytes uploaded ...
# 13000000 bytes uploaded ...
# 14000000 bytes uploaded ...
# 15000000 bytes uploaded ...
# 15608238 bytes uploaded ...
# maximum upload specified(15608238 bytes) has been reached
# 1000000 bytes uploaded ...
# 2000000 bytes uploaded ...
# 3000000 bytes uploaded ...
# 4000000 bytes uploaded ...
# 5000000 bytes uploaded ...
# 6000000 bytes uploaded ...
# 7000000 bytes uploaded ...
# 8000000 bytes uploaded ...
# 9000000 bytes uploaded ...
# 10000000 bytes uploaded ...
# 11000000 bytes uploaded ...
# 12000000 bytes uploaded ...
# 13000000 bytes uploaded ...
# 14000000 bytes uploaded ...
# 15000000 bytes uploaded ...
# ...
